# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# CRIANDO UM DATA FRAME COM DICIONÁRIOS

# %%
s1 = pd.Series([1,2,3,4], name="c1")
s2 = pd.Series([10,20,30,40], name="c2") 

pd.DataFrame({s1.name:s1,s2.name:s2})
# Out:
#    c1  c2
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40

# %%
s1 = pd.Series([1,2,3], name="c1")
s2 = pd.Series([10,20,30,40], name="c2") 

pd.DataFrame({s1.name:s1,s2.name:s2})
# Out:
#     c1  c2
# 0  1.0  10
# 1  2.0  20
# 2  3.0  30
# 3  NaN  40

# %%
df = pd.DataFrame({s1.name:s1,s2.name:s2})

# %%
df.columns
# Out:
# Index(['c1', 'c2'], dtype='object')

# %% [markdown]
# SELEÇÃO DE COLUNAS

# %%
s1 = pd.Series([1,2,3,4], name="c1")
s2 = pd.Series([10,20,30,40], name="c2") 

p = pd.DataFrame({s1.name:s1,s2.name:s2})

# %%
p
# Out:
#    c1  c2
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40

# %%
p[["c1"]] , p["c2"] 
#data frame/ série
# Out:
# (   c1
#  0   1
#  1   2
#  2   3
#  3   4,
#  0    10
#  1    20
#  2    30
#  3    40
#  Name: c2, dtype: int64)

# %%
p[["c1","c2"]]
# Out:
#    c1  c2
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40

# %% [markdown]
# ADIÇÃO DE COLUNAS (ATRIBUIÇÃO ESCALAR, POR CÁLCULO E POR INSERT)

# %%
p["c3"] = "abc"

# %%
p
# Out:
#    c1  c2   c3
# 0   1  10  abc
# 1   2  20  abc
# 2   3  30  abc
# 3   4  40  abc

# %%
p["media_c1"] = np.average(p["c1"]) 
p["c1_c2"] = p["c1"] + p["c2"]

# %%
p
# Out:
#    c1  c2   c3  media_c1  c1_c2
# 0   1  10  abc       2.5     11
# 1   2  20  abc       2.5     22
# 2   3  30  abc       2.5     33
# 3   4  40  abc       2.5     44

# %%
p.insert(1, "entrão", "isso ai")
p
# Out:
#    c1   entrão  c2   c3  media_c1  c1_c2
# 0   1  isso ai  10  abc       2.5     11
# 1   2  isso ai  20  abc       2.5     22
# 2   3  isso ai  30  abc       2.5     33
# 3   4  isso ai  40  abc       2.5     44

# %% [markdown]
# REMOÇÃO DE COLUNAS (DIFERENÇA ENTRE DEL E POP)

# %%
del p["c1_c2"]

# %%
p
# Out:
#    c1   entrão  c2   c3  media_c1
# 0   1  isso ai  10  abc       2.5
# 1   2  isso ai  20  abc       2.5
# 2   3  isso ai  30  abc       2.5
# 3   4  isso ai  40  abc       2.5

# %%
a = p.pop("entrão")

# %%
p
# Out:
#    c1  c2   c3  media_c1
# 0   1  10  abc       2.5
# 1   2  20  abc       2.5
# 2   3  30  abc       2.5
# 3   4  40  abc       2.5

# %%
a
# Out:
# 0    isso ai
# 1    isso ai
# 2    isso ai
# 3    isso ai
# Name: entrão, dtype: object

# %% [markdown]
# APPLY E APPLYMAP

# %%
alugueis = pd.read_csv("/home/mnetto/Documents/Python/houses_to_rent.csv")

# %%
alugueis.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257

# %%
alugueis["hoa_tratado"] = alugueis["hoa"].apply(lambda x: x.replace("R$", "").replace(",",""))

# %%
alugueis
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 0              0     1   240      3         3               4     -
# 1              1     0    64      2         1               1    10
# 2              2     1   443      5         5               4     3
# 3              3     1    73      2         2               1    12
# 4              4     1    19      1         1               0     -
# ...          ...   ...   ...    ...       ...             ...   ...
# 6075        6075     1    50      2         1               1     2
# 6076        6076     1    84      2         2               1    16
# 6077        6077     0    48      1         1               0    13
# 6078        6078     1   160      3         2               2     -
# 6079        6079     1    60      2         1               1     4
#
#          animal      furniture      hoa rent amount property tax  \
# 0         acept      furnished      R$0     R$8,000      R$1,000
# ...

# %%
alugueis[["property tax","hoa","rent amount"]].applymap(lambda x: x.replace("R$", "").replace(",",""))
# Out:
#      property tax   hoa rent amount
# 0            1000     0        8000
# 1             122   540         820
# 2            1417  4172        7000
# 3             150   700        1250
# 4              41     0        1200
# ...           ...   ...         ...
# 6075            0   420        1150
# 6076           63   768        2900
# 6077           42   250         950
# 6078          250     0        3500
# 6079            0   489        1900
#
# [6080 rows x 3 columns]
