# %%
import pandas as pd 
df = pd.read_excel("/home/mnetto/Documents/Python/Pandas/Dados.xlsx")

# %% [markdown]
# USANDO O sort_values

# %%
df.sort_values("FirstName").head()
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 351               413         SC          0   Mr.      Adam        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 351      Barr    NaN               1

# %%
df.sort_values("FirstName", ascending= False).head()
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 901              1513         VC          0   Mr.     Zheng        NaN
# 101               102         EM          0   NaN     Zheng          W
# 216               217         EM          0   NaN    Zainal          T
# 186               187         EM          0   NaN    Yvonne          S
# 862              1435         SC          0   Ms.    Yvonne        NaN
#
#     LastName Suffix  EmailPromotion
# 901       Mu    NaN               0
# 101       Mu    NaN               0
# 216   Arifin    NaN               1
# 186    McKay    NaN               0
# 862    McKay    NaN               0

# %%
#Ordenando por mais de uma coluna 
df.sort_values(["FirstName", "LastName"]).head()
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 351               413         SC          0   Mr.      Adam        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 351      Barr    NaN               1

# %%
df.sort_values(["FirstName", "LastName"], ascending=[True, False]).head()
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 984              1679         VC          0   Mr.      Adam         J.
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 984  Reynolds    Jr.               1

# %%
colunas = ["FirstName", "LastName"] 
ordenacao = ["True", "False"] 

df.sort_values(by = colunas, ascending= ordenacao).head()
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 351               413         SC          0   Mr.      Adam        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 351      Barr    NaN               1
