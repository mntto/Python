# %%
import pandas as pd 
import numpy as np 
alugueis = pd.read_csv("/home/mnetto/Documents/Python/houses_to_rent.csv")
base_copia = alugueis.copy(deep = True)

# %%
base_copia.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257

# %%
# Adicionar coluna através do nome da coluna (igual adicionar um valor numa lista)
base_copia["nova_coluna"] = 78

# %%
base_copia.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257

# %%
del base_copia["nova_coluna"]

# %%
# Adicionar coluna via atributo
base_copia.nova_coluna_atributo = 10

# %%
type(base_copia.nova_coluna_atributo)
# Out:
# int

# %%
#Adicionando coluna via append 
base_copia.append({"nova_coluna": 90}, ignore_index=True)
# Out:
#       Unnamed: 0  city   area  rooms  bathroom  parking spaces floor  \
# 0            0.0   1.0  240.0    3.0       3.0             4.0     -
# 1            1.0   0.0   64.0    2.0       1.0             1.0    10
# 2            2.0   1.0  443.0    5.0       5.0             4.0     3
# 3            3.0   1.0   73.0    2.0       2.0             1.0    12
# 4            4.0   1.0   19.0    1.0       1.0             0.0     -
# ...          ...   ...    ...    ...       ...             ...   ...
# 6076      6076.0   1.0   84.0    2.0       2.0             1.0    16
# 6077      6077.0   0.0   48.0    1.0       1.0             0.0    13
# 6078      6078.0   1.0  160.0    3.0       2.0             2.0     -
# 6079      6079.0   1.0   60.0    2.0       1.0             1.0     4
# 6080         NaN   NaN    NaN    NaN       NaN             NaN   NaN
#
#          animal      furniture      hoa rent amount property tax  \
# 0         acept      furnished      R$0     R$8,000      R$1,000
# ...

# %%
base_copia.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257

# %%
x = base_copia.append({"nova_coluna": 90}, ignore_index=True)

# %% [markdown]
# DIFERENÇA ENTRE ADICIONAR VIA LISTA E VIA ASSIGN

# %%
#lista 
base_copia["nova_coluna2"] = "abc" #altera diretamente a base_copia

# %%
base_copia.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total  \
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257
#
#   nova_coluna2
# 0          abc
# 1          abc
# ...

# %%
#Assign
base_copia.assign(nova_cluna = 10)#Retorna uma novo data framae
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 0              0     1   240      3         3               4     -
# 1              1     0    64      2         1               1    10
# 2              2     1   443      5         5               4     3
# 3              3     1    73      2         2               1    12
# 4              4     1    19      1         1               0     -
# ...          ...   ...   ...    ...       ...             ...   ...
# 6075        6075     1    50      2         1               1     2
# 6076        6076     1    84      2         2               1    16
# 6077        6077     0    48      1         1               0    13
# 6078        6078     1   160      3         2               2     -
# 6079        6079     1    60      2         1               1     4
#
#          animal      furniture      hoa rent amount property tax  \
# 0         acept      furnished      R$0     R$8,000      R$1,000
# ...

# %%
base_copia.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total  \
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257
#
#   nova_coluna2
# 0          abc
# 1          abc
# ...

# %% [markdown]
# SELECIONANDO OS DADOS VIA LOC, SOMANDO E ADICIONANDO O RESULTADO VIA ASSIGN OU LISTA

# %%
colunas = ["rooms", 'bathroom'] 
base_copia.loc[:5, colunas]
# Out:
#    rooms  bathroom
# 0      3         3
# 1      2         1
# 2      5         5
# 3      2         2
# 4      1         1
# 5      1         1

# %%
base_copia["soma"] = base_copia.rooms + base_copia.bathroom

# %%
colunas = ["rooms", 'bathroom', "soma"] 
base_copia.loc[:5, colunas]
# Out:
#    rooms  bathroom  soma
# 0      3         3     6
# 1      2         1     3
# 2      5         5    10
# 3      2         2     4
# 4      1         1     2
# 5      1         1     2

# %% [markdown]
# FUNÇÕES E LAMBDA EM ASSIGN

# %%
#Utilizando uma função 
def funcao_multiplicacao(df) : 
    return df.area * df.rooms

# %%
base_copia.assign(multiplicacao = funcao_multiplicacao).loc[:5, ["area", "rooms", "multiplicacao"]]
# Out:
#    area  rooms  multiplicacao
# 0   240      3            720
# 1    64      2            128
# 2   443      5           2215
# 3    73      2            146
# 4    19      1             19
# 5    13      1             13

# %%
#Utilizando um lambda
base_copia.assign(soma_lambda = lambda x: x.rooms + x.bathroom,multiplicacao = funcao_multiplicacao).loc[:5,:]
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
# 5           5     1    13      1         1               0     2      acept
#
#        furniture      hoa rent amount property tax fire insurance     total  \
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# ...
