# %%
import pandas as pd
import numpy as np 

alugueis = pd.read_csv("/home/mnetto/Documents/Python/houses_to_rent.csv")

# %%
# Operadores lógicos
# & - E
# | - OU
# ~ - NÃO
alugueis[(alugueis.rooms > 2) & (alugueis.bathroom > 3)]
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 2              2     1   443      5         5               4     3
# 13            13     1   375      4         5               5     1
# 24            24     1   180      3         5               3     3
# 27            27     1   300      3         4               2     9
# 32            32     1   250      3         4               2     -
# ...          ...   ...   ...    ...       ...             ...   ...
# 6063        6063     1   210      4         4               3    13
# 6067        6067     1   280      4         4               3    17
# 6070        6070     1   200      4         5               3     2
# 6071        6071     0   600      5         5               4     -
# 6072        6072     1   200      4         4               4    21
#
#          animal      furniture      hoa rent amount property tax  \
# 2         acept      furnished  R$4,172     R$7,000      R$1,417
# 13        acept  not furnished  R$4,793    R$15,000      R$2,805
# 24        acept  not furnished  R$2,900     R$8,100          R$0
# 27        acept      furnished  R$2,000    R$14,000      R$1,084
# 32        acept  not furnished    R$300     R$3,480        R$360
# ...         ...            ...      ...         ...          ...
# 6063  not acept      furnished  R$2,500     R$4,000          R$0
# 6067      acept      furnished  R$2,400     R$6,553          R$0
# 6070      acept  not furnished  R$2,600     R$4,500        R$834
# 6071      acept  not furnished  R$3,300     R$5,000        R$916
# 6072      acept      furnished  R$2,000    R$10,000        R$862
#
#      fire insurance     total
# 2              R$89  R$12,680
# 13            R$191  R$22,790
# 24            R$103  R$11,100
# 27            R$178  R$17,260
# 32             R$53   R$4,193
# ...             ...       ...
# 6063           R$51   R$6,551
# 6067           R$84   R$9,037
# 6070           R$58   R$7,992
# 6071           R$76   R$9,292
# 6072          R$127  R$12,990
#
# [1270 rows x 14 columns]

# %%
alugueis[~(alugueis.area <= 300)]
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 2              2     1   443      5         5               4     3  acept
# 13            13     1   375      4         5               5     1  acept
# 23            23     1   320      3         3               4     -  acept
# 41            41     1   800      4         5               4     9  acept
# 42            42     1   340      3         4               3     -  acept
# ...          ...   ...   ...    ...       ...             ...   ...    ...
# 6045        6045     1   600      5         5               6     -  acept
# 6055        6055     0   306      3         2               2     -  acept
# 6060        6060     1   384      3         5               3     -  acept
# 6066        6066     1   350      3         2               4     -  acept
# 6071        6071     0   600      5         5               4     -  acept
#
#           furniture      hoa rent amount property tax fire insurance     total
# 2         furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 13    not furnished  R$4,793    R$15,000      R$2,805          R$191  R$22,790
# 23    not furnished      R$0     R$9,000      R$1,000          R$136  R$10,140
# 41    not furnished  R$6,000    R$15,000      R$3,334          R$191  R$24,530
# 42        furnished      R$0     R$9,800        R$392          R$148  R$10,340
# ...             ...      ...         ...          ...            ...       ...
# 6045  not furnished      R$0    R$12,750      R$1,059          R$192  R$14,000
# 6055  not furnished  Incluso     R$2,500        R$422           R$38   R$2,960
# 6060  not furnished      R$0    R$10,000      R$1,050          R$151  R$11,200
# 6066  not furnished      R$0    R$12,500      R$1,334          R$188  R$14,020
# 6071  not furnished  R$3,300     R$5,000        R$916           R$76   R$9,292
#
# [606 rows x 14 columns]

# %%
filtro = ((alugueis.rooms == 3) & (alugueis.floor == "5")) | (alugueis.area > 550)

# %%
filtro
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6075    False
# 6076    False
# 6077    False
# 6078    False
# 6079    False
# Length: 6080, dtype: bool

# %%
alugueis[filtro]
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 41            41     1   800      4         5               4     9
# 44            44     0   650      5         4               8     -
# 63            63     1   750      7         6               5     -
# 180          180     1   170      3         2               2     5
# 226          226     1   122      3         4               3     5
# ...          ...   ...   ...    ...       ...             ...   ...
# 5908        5908     1   105      3         2               2     5
# 5941        5941     1   600      4         5               6     -
# 5968        5968     1   210      3         4               3     5
# 6045        6045     1   600      5         5               6     -
# 6071        6071     0   600      5         5               4     -
#
#          animal      furniture      hoa rent amount property tax  \
# 41        acept  not furnished  R$6,000    R$15,000      R$3,334
# 44        acept      furnished      R$0     R$8,500        R$442
# 63        acept      furnished      R$0     R$5,800        R$559
# 180   not acept  not furnished  R$2,199     R$5,000        R$423
# 226       acept  not furnished  Incluso     R$4,500          R$0
# ...         ...            ...      ...         ...          ...
# 5908      acept  not furnished  R$1,661     R$1,000        R$290
# 5941      acept  not furnished      R$0     R$6,000      R$3,000
# 5968      acept      furnished  R$4,100     R$9,945      R$1,000
# 6045      acept  not furnished      R$0    R$12,750      R$1,059
# 6071      acept  not furnished  R$3,300     R$5,000        R$916
#
#      fire insurance     total
# 41            R$191  R$24,530
# 44            R$128   R$9,070
# 63             R$88   R$6,447
# 180            R$64   R$7,686
# 226            R$58   R$4,558
# ...             ...       ...
# 5908           R$13   R$2,964
# 5941           R$51   R$9,051
# 5968          R$127  R$15,170
# 6045          R$192  R$14,000
# 6071           R$76   R$9,292
#
# [194 rows x 14 columns]

# %%
alugueis[~filtro]
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 0              0     1   240      3         3               4     -
# 1              1     0    64      2         1               1    10
# 2              2     1   443      5         5               4     3
# 3              3     1    73      2         2               1    12
# 4              4     1    19      1         1               0     -
# ...          ...   ...   ...    ...       ...             ...   ...
# 6075        6075     1    50      2         1               1     2
# 6076        6076     1    84      2         2               1    16
# 6077        6077     0    48      1         1               0    13
# 6078        6078     1   160      3         2               2     -
# 6079        6079     1    60      2         1               1     4
#
#          animal      furniture      hoa rent amount property tax  \
# 0         acept      furnished      R$0     R$8,000      R$1,000
# 1         acept  not furnished    R$540       R$820        R$122
# 2         acept      furnished  R$4,172     R$7,000      R$1,417
# 3         acept  not furnished    R$700     R$1,250        R$150
# 4     not acept  not furnished      R$0     R$1,200         R$41
# ...         ...            ...      ...         ...          ...
# 6075      acept  not furnished    R$420     R$1,150          R$0
# 6076  not acept      furnished    R$768     R$2,900         R$63
# 6077      acept  not furnished    R$250       R$950         R$42
# 6078  not acept  not furnished      R$0     R$3,500        R$250
# 6079      acept      furnished    R$489     R$1,900          R$0
#
#      fire insurance     total
# 0             R$121   R$9,121
# 1              R$11   R$1,493
# 2              R$89  R$12,680
# 3              R$16   R$2,116
# 4              R$16   R$1,257
# ...             ...       ...
# 6075           R$15   R$1,585
# 6076           R$37   R$3,768
# 6077           R$13   R$1,255
# 6078           R$53   R$3,803
# 6079           R$25   R$2,414
#
# [5886 rows x 14 columns]
