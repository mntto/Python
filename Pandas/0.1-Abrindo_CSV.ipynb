# %%
#Importando pandas 
import pandas as pd

# %%
#Abrindo o csv, passando sua localidade, passando sua codificação, passando que ele é separado por ';' e passando a onde seu cabeçalho começa  
df = pd.read_csv("/home/mnetto/Documents/Python/Pandas/Dados aula 1.csv", encoding = "UTF-8", sep= ";", header=0)

# %%
df.head()
# Out:
#    AddressID          AddressLine1 AddressLine2     City  StateProvinceID  \
# 0          1         1970 Napa Ct.          NaN  Bothell               79
# 1          2    9833 Mt. Dias Blv.          NaN  Bothell               79
# 2          3  7484 Roundtree Drive          NaN  Bothell               79
# 3          4      9539 Glenside Dr          NaN  Bothell               79
# 4          5         1226 Shoe St.          NaN  Bothell               79
#
#   PostalCode                                 SpatialLocation  \
# 0      98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1      98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2      98011  0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3      98011  0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4      98011  0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# ...

# %%
#selecionando algumas colunas, usecols determina quais colunas usar 
df = pd.read_csv("/home/mnetto/Documents/Python/Pandas/Dados aula 1.csv", encoding = "UTF-8", sep= ";", usecols=["AddressID","AddressLine1"])

# %%
df.head()
# Out:
#    AddressID          AddressLine1
# 0          1         1970 Napa Ct.
# 1          2    9833 Mt. Dias Blv.
# 2          3  7484 Roundtree Drive
# 3          4      9539 Glenside Dr
# 4          5         1226 Shoe St.

# %%
#Lendo X linhas do csv, nrows determina o número de linhas 
df = pd.read_csv("/home/mnetto/Documents/Python/Pandas/Dados aula 1.csv", encoding = "UTF-8", sep= ";",usecols=["AddressID","AddressLine1"], nrows=200)

# %%
df.head(), df.shape
# Out:
# (   AddressID          AddressLine1
#  0          1         1970 Napa Ct.
#  1          2    9833 Mt. Dias Blv.
#  2          3  7484 Roundtree Drive
#  3          4      9539 Glenside Dr
#  4          5         1226 Shoe St.,
#  (200, 2))
